# %%
# Logan Caldwell pandas hw
# importing dependencies

import pandas as pd
import numpy as np

# %%
# Read in csv file and assign dataframes

school_data_to_load = "schools_complete.csv"
student_data_to_load = "students_complete.csv"

school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# %%
school_data.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
student_data.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
#Merge data to one df

school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

school_data_complete.head(10)
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
# 5           5      Bryan Miranda      M   9th  Huang High School
# 6           6      Sheena Carter      F  11th  Huang High School
# 7           7       Nicole Baker      F  12th  Huang High School
# 8           8       Michael Roth      M  10th  Huang High School
# 9           9     Matthew Greene      M  10th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635
# 5             94          94          0  District  2917  1910635
# 6             82          80          0  District  2917  1910635
# 7             96          69          0  District  2917  1910635
# 8             95          87          0  District  2917  1910635
# 9             96          84          0  District  2917  1910635

# %%
# District summaries

print("District Summary: ")
print()

tot_num_schools = int(len(school_data_complete["School ID"].unique()))
print(f"The total number of schools is: {tot_num_schools}")

tot_num_students = len(school_data_complete["student_name"])
print(f"The total number of students is: {tot_num_students}")

tot_budget = sum(school_data_complete["budget"].unique())
print(f"The total budget is: {tot_budget}")

avg_math_score = round(sum(school_data_complete["math_score"])/tot_num_students, 2)
print(f"The average math score is: {avg_math_score}")

avg_reading_score = round(sum(school_data_complete["reading_score"])/tot_num_students, 2)
print(f"The average reading score is: {avg_reading_score}")

avg_passing_ie_tot_score = round((avg_math_score + avg_reading_score)/2, 2)
print(f"The average passing (i.e., overall average) score is: {avg_passing_ie_tot_score}")

df_passing_math_students = school_data_complete[school_data_complete["math_score"] >= 70]
num_passing_math_students = int(len(df_passing_math_students))
pct_passing_math_students = round(((num_passing_math_students/tot_num_students)*100), 2)
print(f"Percentage of passing math students is: {pct_passing_math_students}%")

df_passing_reading_students = school_data_complete[school_data_complete["reading_score"] >= 70]
num_passing_reading_students = int(len(df_passing_reading_students))
pct_passing_reading_students = round(((num_passing_reading_students/tot_num_students)*100), 2)
print(f"Percentage of passing reading students is: {pct_passing_reading_students}%")


dict_district_summary = {"Num_schools":tot_num_schools, "Num_students":tot_num_students, "Tot_budget":tot_budget, 
                         "Avg_math":avg_math_score, "Avg_reading":avg_reading_score, 
                         "avg_passing":avg_passing_ie_tot_score, "pct_math_pass":pct_passing_math_students, 
                         "pct_reading_pass":pct_passing_reading_students}
df_district_summary = pd.DataFrame(data=dict_district_summary, index = ['Info'], columns = ["Num_schools","Num_students","Tot_budget",
                                                                          "Avg_math","Avg_reading","avg_passing",
                                                                          "pct_math_pass","pct_reading_pass"])
df_district_summary
# Out:
# District Summary:
#
# The total number of schools is: 15
# The total number of students is: 39170
# The total budget is: 24649428
# The average math score is: 78.99
# The average reading score is: 81.88
# The average passing (i.e., overall average) score is: 80.44
# Percentage of passing math students is: 74.98%
# Percentage of passing reading students is: 85.81%
#       Num_schools  Num_students  Tot_budget  Avg_math  Avg_reading  \
# Info           15         39170    24649428     78.99        81.88
#
#       avg_passing  pct_math_pass  pct_reading_pass
# Info        80.44          74.98             85.81

# %%
school_data_complete["percent_math_pass"] = pct_passing_math_students

# %%
school_data_complete["percent_reading_pass"] = pct_passing_reading_students

# %%
school_data_complete["overall_pass"] = 80.44

# %%
# School summaries

school_data_complete_grouped_by_school = school_data_complete.groupby("school_name")
school_data_complete_grouped_by_school.head()
# Out:
#        Student ID       student_name gender grade            school_name  \
# 0               0       Paul Bradley      M   9th      Huang High School
# 1               1       Victor Smith      M  12th      Huang High School
# 12265              74.98                 85.81         80.44
# 12266              74.98                 85.81         80.44
# 13730              74.98                 85.81         80.44
# 13731              74.98                 85.81         80.44
# 13732              74.98                 85.81         80.44
# 13733              74.98                 85.81         80.44
# 13734              74.98                 85.81         80.44
# ...                  ...                   ...           ...
# 23274              74.98                 85.81         80.44
# 23275              74.98                 85.81         80.44
# 23276              74.98                 85.81         80.44
# 23277              74.98                 85.81         80.44
# 23278              74.98                 85.81         80.44
# 24236              74.98                 85.81         80.44
# 24237              74.98                 85.81         80.44
# 24238              74.98                 85.81         80.44
# 24239              74.98                 85.81         80.44
# 24240              74.98                 85.81         80.44
# 26036              74.98                 85.81         80.44
# 26037              74.98                 85.81         80.44
# 26038              74.98                 85.81         80.44
# 26039              74.98                 85.81         80.44
# 26040              74.98                 85.81         80.44
# 30035              74.98                 85.81         80.44
# 30036              74.98                 85.81         80.44
# 30037              74.98                 85.81         80.44
# 30038              74.98                 85.81         80.44
# 30039              74.98                 85.81         80.44
# 34796              74.98                 85.81         80.44
# 34797              74.98                 85.81         80.44
# 34798              74.98                 85.81         80.44
# 34799              74.98                 85.81         80.44
# 34800              74.98                 85.81         80.44
# 37535              74.98                 85.81         80.44
# 37536              74.98                 85.81         80.44
# 37537              74.98                 85.81         80.44
# 37538              74.98                 85.81         80.44
# 37539              74.98                 85.81         80.44
#
# [75 rows x 14 columns]

# %%
# School summaries cont.

tot_student = school_data_complete_grouped_by_school["school_name"].value_counts()
tot_student.head()
# Out:
# school_name           school_name
# Bailey High School    Bailey High School      4976
# Cabrera High School   Cabrera High School     1858
# Figueroa High School  Figueroa High School    2949
# Ford High School      Ford High School        2739
# Griffin High School   Griffin High School     1468
# Name: school_name, dtype: int64

# %%
school_type = school_data_complete_grouped_by_school["type"]
school_type.head()
# Out:
# 0        District
# 1        District
# 2        District
# 3        District
# 4        District
# 2917     District
# 2918     District
# 2919     District
# 2920     District
# 2921     District
# 5866      Charter
# 5867      Charter
# 5868      Charter
# 5869      Charter
# 5870      Charter
# 7627     District
# 7628     District
# 7629     District
# 7630     District
# 7631     District
# 12262     Charter
# 12263     Charter
# 12264     Charter
# 12265     Charter
# 12266     Charter
# 13730     Charter
# 13731     Charter
# 13732     Charter
# 13733     Charter
# 13734     Charter
#            ...
# 23274     Charter
# 23275     Charter
# 23276     Charter
# 23277     Charter
# 23278     Charter
# 24236     Charter
# 24237     Charter
# 24238     Charter
# 24239     Charter
# 24240     Charter
# 26036    District
# 26037    District
# 26038    District
# 26039    District
# 26040    District
# 30035    District
# 30036    District
# 30037    District
# 30038    District
# 30039    District
# 34796    District
# 34797    District
# 34798    District
# 34799    District
# 34800    District
# 37535     Charter
# 37536     Charter
# 37537     Charter
# 37538     Charter
# 37539     Charter
# Name: type, Length: 75, dtype: object

# %%
tot_student = school_data_complete_grouped_by_school["student_name"].count()
# tot_student.head()

# %%
total_school_budg = float(school_data_complete_grouped_by_school["budget"].mean())
# total_school_budg.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-353-4b3ebd9bc666> in <module>
# ----> 1 total_school_budg = float(school_data_complete_grouped_by_school["budget"].mean())
#       2 # total_school_budg.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     116             return converter(self.iloc[0])
#     117         raise TypeError("cannot convert the series to "
# --> 118                         "{0}".format(str(converter)))
#     119
#     120     return wrapper
#
# TypeError: cannot convert the series to <class 'float'>

# %%
per_student_budg = (total_school_budg/(school_data_complete_grouped_by_school["Student ID"].nunique()))

# %%
avg_math_score = school_data_complete_grouped_by_school["math_score"].mean()

# %%
avg_reading_score = school_data_complete_grouped_by_school["reading_score"].mean()

# %%
# percent_pass_math = ((school_data_complete_grouped_by_school[(school_data_complete_grouped_by_school["math_score"] >= 70), :])/(school_data_complete_grouped_by_school["Student ID"].nunique()))

# df_passing_math_students = school_data_complete[school_data_complete["math_score"] >= 70]
# num_passing_math_students = int(len(df_passing_math_students))
# pct_passing_math_students = round(((num_passing_math_students/tot_num_students)*100), 2)
# print(f"Percentage of passing math students is: {pct_passing_math_students}%")

# %%
school_summary_table = pd.DataFrame({
                                    "school_type": school_type,
                                    "total_students": tot_student,
                                    "total_school_budg": total_school_budg,
                                    "per_student_budg": per_student_budg,
                                    "avg_math_score": avg_math_score,
                                    "avg_reading_score": avg_reading_score,
                                    "%_pass_math": "percent_pass_math",
                                    "%_pass_reading": "percent_pass_reading",
                                    "overall_pass_rate": "overall_pass_rate" 
                                    })
school_summary_table.head(10)
# Out:
#                                                              school_type  \
# school_name
# Bailey High School     (Bailey High School, [District, District, Dist...
# Cabrera High School    (Cabrera High School, [Charter, Charter, Chart...
# Figueroa High School   (Figueroa High School, [District, District, Di...
# Ford High School       (Ford High School, [District, District, Distri...
# Griffin High School    (Griffin High School, [Charter, Charter, Chart...
# Hernandez High School  (Hernandez High School, [District, District, D...
# Holden High School     (Holden High School, [Charter, Charter, Charte...
# Huang High School      (Huang High School, [District, District, Distr...
# Johnson High School    (Johnson High School, [District, District, Dis...
# Pena High School       (Pena High School, [Charter, Charter, Charter,...
#
#                        total_students  total_school_budg  per_student_budg  \
# school_name
# Bailey High School               4976            3124928             628.0
# Cabrera High School              1858            1081356             582.0
# Figueroa High School             2949            1884411             639.0
# Ford High School                 2739            1763916             644.0
# Griffin High School              1468             917500             625.0
# Hernandez High School            4635            3022020             652.0
# Holden High School                427             248087             581.0
# Huang High School                2917            1910635             655.0
# Johnson High School              4761            3094650             650.0
# Pena High School                  962             585858             609.0
#
#                        avg_math_score  avg_reading_score        %_pass_math  \
# school_name
# Bailey High School          77.048432          81.033963  percent_pass_math
# Cabrera High School         83.061895          83.975780  percent_pass_math
# Figueroa High School        76.711767          81.158020  percent_pass_math
# Ford High School            77.102592          80.746258  percent_pass_math
# Griffin High School         83.351499          83.816757  percent_pass_math
# Hernandez High School       77.289752          80.934412  percent_pass_math
# Holden High School          83.803279          83.814988  percent_pass_math
# Huang High School           76.629414          81.182722  percent_pass_math
# Johnson High School         77.072464          80.966394  percent_pass_math
# Pena High School            83.839917          84.044699  percent_pass_math
#
#                              %_pass_reading  overall_pass_rate
# school_name
# Bailey High School     percent_pass_reading  overall_pass_rate
# Cabrera High School    percent_pass_reading  overall_pass_rate
# Figueroa High School   percent_pass_reading  overall_pass_rate
# Ford High School       percent_pass_reading  overall_pass_rate
# Griffin High School    percent_pass_reading  overall_pass_rate
# Hernandez High School  percent_pass_reading  overall_pass_rate
# Holden High School     percent_pass_reading  overall_pass_rate
# Huang High School      percent_pass_reading  overall_pass_rate
# Johnson High School    percent_pass_reading  overall_pass_rate
# Pena High School       percent_pass_reading  overall_pass_rate
